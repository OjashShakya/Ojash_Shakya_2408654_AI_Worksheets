# %% [markdown]
# <a href="https://colab.research.google.com/github/OjashShakya/Ojash_Shakya_2408654_AI_Worksheets/blob/main/2408654_OjashShakya_Worksheet_W1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Name: Ojash Shakya
# ### ID: 2408654

# %% [markdown]
# # Worksheet Week 1

# %% [markdown]
# # Getting Started with Image Processing with Python

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# ## Installing Pillow
#
# Pillow is a Python Imaging Library (PIL) fork that provides easy-to-use methods for opening,
# manipulating, and saving images.

# %%
# !pip install pillow

# %% [markdown]
#  ## Exercise- 1

# %% [markdown]
# ### 1. Read and display the image.
#
# • Read the image using the Pillow library and display it.

# %%
image_colored = Image.open ("/content/drive/MyDrive/6th Sem/Artificial Intelligence and Machine Learning/Week 1/image.png")
display(image_colored)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=573x568>

# %% [markdown]
# • You can also use matplotlib to display the image.

# %%
plt.imshow(image_colored)
plt.show()

# %% [markdown]
# ### Getting Image Properties

# %%
print ( "Image Format : " , image_colored.format )
print ( "Image Size : " , image_colored.size )
print ( "Image Mode : " , image_colored.mode )
# Out:
# Image Format :  PNG
# Image Size :  (573, 568)
# Image Mode :  P

# %% [markdown]
# ### Converting to RGB

# %%
image_colored = image_colored.convert ("RGB")
print(image_colored.mode)
# Out:
# RGB

# %% [markdown]
# ### Getting Shape and Size of an Image Using PIL

# %%
# Get the size (width, height) and number of channels (RGB)
width, height = image_colored.size
channels = len(image_colored.getbands())  # For RGB, it will be 3

print(f"Image shape (RGB): ({height}, {width}, {channels})")

image_size_colored = width * height * channels
print(f"Image size (RGB): {image_size_colored}")
# Out:
# Image shape (RGB): (568, 573, 3)
# Image size (RGB): 976392

# %% [markdown]
# ### 2. Display only the top left corner of 100x100 pixels.
# • Extract the top-left corner of the image (100x100 pixels) and display it using NumPy and
# Array Indexing

# %%
image_array = np.array(image_colored)

# Extract the top-left 100x100 pixels using array indexing
top_left_corner_np = image_array[0:100, 0:100]

# Display the cropped image using matplotlib
plt.imshow(top_left_corner_np)
plt.title('Top-Left 100x100 pixels (NumPy)')
plt.axis('off') # Hide axes for cleaner display
plt.show()

# converting it back to a PIL Image if needed:
top_left_corner_pil = Image.fromarray(top_left_corner_np)
display(top_left_corner_pil)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %% [markdown]
# ### 3. Show the three color channels (R, G, B).
# • Separate the image into its three color channels (Red, Green, and Blue) and display them
# individually, labeling each channel as R, G, and B.{Using NumPy.}

# %%
# Convert the Pillow image to a NumPy array
image_array_colored = np.array(image_colored)

# Display the shape of the NumPy array (height, width, channels)
print("Shape of the image array:", image_array_colored.shape)

red_channel = image_array_colored.copy()
red_channel [:, :, 1] = 0
red_channel [:, :, 2] = 0
# print("Red Channel:\n", red_channel)
display(red_channel)
# Out:
# Shape of the image array: (568, 573, 3)
# array([[[ 73,   0,   0],
#         [ 73,   0,   0],
#         [ 79,   0,   0],
#         ...,
#         [107,   0,   0],
#         [  1,   0,   0],
#         [  1,   0,   0]],
#
#        [[ 73,   0,   0],
#         [ 69,   0,   0],
#         [ 73,   0,   0],
#         ...,
#         [107,   0,   0],
#         [  1,   0,   0],
#         [  1,   0,   0]],
#
#        [[ 73,   0,   0],
#         [ 73,   0,   0],
#         [ 82,   0,   0],
#         ...,
#         [107,   0,   0],
#         [  1,   0,   0],
#         [  1,   0,   0]],
#
#        ...,
#
#        [[  6,   0,   0],
#         [  9,   0,   0],
#         [  9,   0,   0],
#         ...,
#         [108,   0,   0],
#         [  1,   0,   0],
#         [  1,   0,   0]],
#
#        [[  6,   0,   0],
#         [  9,   0,   0],
#         [  9,   0,   0],
#         ...,
#         [108,   0,   0],
#         [  1,   0,   0],
#         [  1,   0,   0]],
#
#        [[  6,   0,   0],
# ...

# %%
green_channel = image_array_colored.copy()
green_channel [:, :, 0] = 0
green_channel [:, :, 2] = 0
# print("Green Channel:\n", green_channel)
display(green_channel)
# Out:
# array([[[  0,  70,   0],
#         [  0,  70,   0],
#         [  0,  72,   0],
#         ...,
#         [  0, 106,   0],
#         [  0,   1,   0],
#         [  0,   1,   0]],
#
#        [[  0,  70,   0],
#         [  0,  63,   0],
#         [  0,  70,   0],
#         ...,
#         [  0, 106,   0],
#         [  0,   1,   0],
#         [  0,   1,   0]],
#
#        [[  0,  67,   0],
#         [  0,  67,   0],
#         [  0,  77,   0],
#         ...,
#         [  0, 106,   0],
#         [  0,   1,   0],
#         [  0,   1,   0]],
#
#        ...,
#
#        [[  0,   5,   0],
#         [  0,   9,   0],
#         [  0,   9,   0],
#         ...,
#         [  0,  64,   0],
#         [  0,   1,   0],
#         [  0,   1,   0]],
#
#        [[  0,   5,   0],
#         [  0,   9,   0],
#         [  0,   9,   0],
#         ...,
#         [  0,  64,   0],
#         [  0,   1,   0],
#         [  0,   1,   0]],
#
#        [[  0,   5,   0],
#         [  0,   5,   0],
#         [  0,   5,   0],
# ...

# %%
blue_channel = image_array_colored.copy()
blue_channel [:, :, 0] = 0
blue_channel [:, :, 1] = 0
# print("Blue Channel:\n", blue_channel)
display(blue_channel)
# Out:
# array([[[ 0,  0, 33],
#         [ 0,  0, 33],
#         [ 0,  0, 34],
#         ...,
#         [ 0,  0, 82],
#         [ 0,  0,  2],
#         [ 0,  0,  2]],
#
#        [[ 0,  0, 33],
#         [ 0,  0, 27],
#         [ 0,  0, 33],
#         ...,
#         [ 0,  0, 82],
#         [ 0,  0,  2],
#         [ 0,  0,  2]],
#
#        [[ 0,  0, 31],
#         [ 0,  0, 31],
#         [ 0,  0, 36],
#         ...,
#         [ 0,  0, 82],
#         [ 0,  0,  2],
#         [ 0,  0,  2]],
#
#        ...,
#
#        [[ 0,  0,  8],
#         [ 0,  0, 11],
#         [ 0,  0, 11],
#         ...,
#         [ 0,  0, 24],
#         [ 0,  0,  2],
#         [ 0,  0,  2]],
#
#        [[ 0,  0,  8],
#         [ 0,  0, 11],
#         [ 0,  0, 11],
#         ...,
#         [ 0,  0, 24],
#         [ 0,  0,  2],
#         [ 0,  0,  2]],
#
#        [[ 0,  0,  8],
#         [ 0,  0,  8],
#         [ 0,  0,  8],
#         ...,
#         [ 0,  0, 21],
#         [ 0,  0,  2],
#         [ 0,  0,  2]]], dtype=uint8)

# %% [markdown]
# ### 4. Modify the top 100 ×100 pixels to a value of 210 and display the resulting image:
# • Modify the pixel values of the top-left 100 × 100 region to have a value of 210 (which is a
# light gray color), and then display the modified image

# %%
modified_image_array = image_array_colored.copy()

# Set the top-left 100x100 pixels to a value of 210
modified_image_array[0:100, 0:100, :] = 210
modified_image_pil = Image.fromarray(modified_image_array)

display(modified_image_pil)

plt.imshow(modified_image_pil)
plt.title('Image with Top-Left 100x100 Pixels Modified')
plt.axis('off')
plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=573x568>

# %% [markdown]
# ## Exercise- 2:

# %% [markdown]
# ### 1. Load and display a grayscale image.
# • Load a grayscale image using the Pillow library.
#
# • Display the grayscale image using matplotlib.

# %%
# Load image and convert to grayscale
image_grayed = Image.open("/content/drive/MyDrive/6th Sem/Artificial Intelligence and Machine Learning/Week 1/image.png").convert("L")

display(image_grayed)

plt.imshow(image_grayed)
plt.show()
# Out:
# <PIL.Image.Image image mode=L size=573x568>

# %% [markdown]
# ### 2. Extract and display the middle section of the image (150 pixels).
#
# • Extract a 150 pixel section from the center of the image using NumPy array slicing.
#
# • Display this cropped image using matplotlib.

# %%
# Convert the Pillow image to a NumPy array
image_array_gray = np.array(image_grayed)

height, width = image_array_gray.shape

start_row = (height - 150) // 2
end_row = start_row + 150

start_col = (width - 150) // 2
end_col = start_col + 150

# Ensure indices are within bounds (important for smaller images)
start_row = max(0, start_row)
end_row = min(height, end_row)
start_col = max(0, start_col)
end_col = min(width, end_col)

# Extract the middle section using NumPy array slicing
middle_section = image_array_gray[start_row:end_row, start_col:end_col]

# Display the cropped image using matplotlib
plt.imshow(middle_section, cmap='gray')
plt.title('Middle 150x150 Pixel Section')
plt.axis('off')
plt.show()

# Display as PIL Image as well
middle_section_pil = Image.fromarray(middle_section)
display(middle_section_pil)
# Out:
# <PIL.Image.Image image mode=L size=150x150>

# %% [markdown]
# ### 3. Apply a simple threshold to the image (e.g., set all pixel values below 100 to 0).
# • Apply a threshold to the grayscale image: set all pixel values below 100 to 0, and all values
#
# above 100 to 255 (creating a binary image).
# • Display the resulting binary image.

# %%
thresholded_image_array = image_array_gray.copy()

# Apply the threshold: values below 100 to 0, values >= 100 to 255
thresholded_image_array[thresholded_image_array < 100] = 0
thresholded_image_array[thresholded_image_array >= 100] = 255

# Convert the thresholded NumPy array back to a PIL Image
thresholded_image_pil = Image.fromarray(thresholded_image_array.astype(np.uint8))

# Display the resulting binary image using display()
display(thresholded_image_pil)

plt.imshow(thresholded_image_pil, cmap='gray')
plt.title('Thresholded Binary Image (Threshold = 100)')
plt.axis('off')
plt.show()
# Out:
# <PIL.Image.Image image mode=L size=573x568>

# %% [markdown]
# ###4. Rotate the image 90 degrees clockwise and display the result.
# • Rotatethe image by90degrees clockwise using the Pillow rotate method or by manipulating
# the image array.
#
# • Display the rotated image using matplotlib.

# %%
# Rotate the image 90 degrees clockwise
rotated_image_pil = image_colored.rotate(-90, expand=True)
display(rotated_image_pil)

plt.imshow(rotated_image_pil, cmap='gray')
plt.title('Image Rotated 90 Degrees Clockwise')
plt.axis('off')
plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=568x573>

# %% [markdown]
# ### 5. Convert the grayscale image to an RGB image.
# • Convert the grayscale image into an RGB image where the grayscale values are replicated
# across all three channels (R, G, and B).
#
# • Display the converted RGB image using matplotlib

# %%
rgb_image = image_grayed.convert('RGB')
display(rgb_image)

plt.imshow(rgb_image)
plt.title('Grayscale Image Converted to RGB')
plt.axis('off')
plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=573x568>

# %% [markdown]
# # Image Compression and Decompression using PCA.

# %% [markdown]
# ### 1. Load and Prepare Data:
#
# • Fetch an image of you choice.{If colour convert to grayscale}

# %%
image_colored = Image.open ("/content/drive/MyDrive/6th Sem/Artificial Intelligence and Machine Learning/Week 1/image.png")

image_gray = image_colored.convert('L')
display(image_gray)
# Out:
# <PIL.Image.Image image mode=L size=573x568>

# %% [markdown]
# • Center the dataset- Standaridze the Data.

# %%
image_array_centered = np.array(image_gray)

# Calculate the mean of all pixel values
mean_pixel_value = np.mean(image_array_centered)

# Subtract the mean from each pixel to center the data
image_array_centered = image_array_centered - mean_pixel_value

# Print the shape and mean to verify
print(f"Shape of the centered image array: {image_array_centered.shape}")
print(f"Mean of the centered image array: {np.mean(image_array_centered): 4f}")
# Out:
# Shape of the centered image array: (568, 573)
# Mean of the centered image array: -0.000000

# %% [markdown]
# • Calculate the covaraince matrix of the Standaridze data.

# %%
reshaped_image_data = image_array_centered.reshape(-1, 1)
print(f"Shape of the reshaped image data: {reshaped_image_data.shape}")

covariance_matrix = np.cov(reshaped_image_data, rowvar=False)
print(f"Shape of the covariance matrix: {covariance_matrix.shape}")

# Print the covariance matrix
print("Covariance Matrix:", covariance_matrix)
# Out:
# Shape of the reshaped image data: (325464, 1)
# Shape of the covariance matrix: ()
# Covariance Matrix: 2821.9940584998853

# %% [markdown]
# ### 2. Eigen Decomposition and Identifying Principal Components:
# • Compute Eigen Values and Eigen Vectors.

# %%
# Convert image to numpy array
image_array = np.array(image_gray, dtype=float)

mean = np.mean(image_array, axis=0)
centered_data = image_array - mean

print("Shape:", centered_data.shape)

# Covariance matrix
cov_matrix = np.cov(centered_data, rowvar=False)
print("Covariance matrix shape:", cov_matrix.shape)

eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)
print("Eigenvalues shape:", eigenvalues.shape)
print("Eigenvectors shape:", eigenvectors.shape)
# Out:
# Shape: (568, 573)
# Covariance matrix shape: (573, 573)
# Eigenvalues shape: (573,)
# Eigenvectors shape: (573, 573)

# %% [markdown]
# • Sort the eigenvalues in descending order and choose the top k eigenvectors corresponding to
# the highest eigenvalues.

# %%
sorted_indices = np.argsort(eigenvalues)[::-1]

eigenvalues = eigenvalues[sorted_indices]
eigenvectors = eigenvectors[:, sorted_indices]

# %% [markdown]
# • Identify the Principal Components with the help of cumulative Sum plot

# %%
explained_variance_ratio = eigenvalues / np.sum(eigenvalues)
cumulative_variance = np.cumsum(explained_variance_ratio)

plt.figure(figsize=(6,4))
plt.plot(cumulative_variance)
plt.title("Cumulative Explained Variance")
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Variance")
plt.grid(True)
plt.show()

# %% [markdown]
# 3. Reconstruction and Experiment:
#
# • Reconstruction: Transform the original data by multiplying it with the selected eigenvec
# tors(PCs) to obtain a lower-dimensional representation.
#
# • Experiments: Pick Four different combination of principal components with various ex
# plained variance value and compare the result.
#
# • Display the Results and Evaluate.

# %%
k_values = [10, 30, 50, 100, 150]

reconstructed_images = []

for k in k_values:
    components = eigenvectors[:, :k]
    compressed_data = np.dot(centered_data, components)
    decompressed_data = np.dot(compressed_data, components.T) + mean
    reconstructed_images.append(decompressed_data)

plt.figure(figsize=(12,8))

# Original Image
plt.subplot(2,3,1)
plt.imshow(image_array, cmap='gray')
plt.title("Original Image")
plt.axis("off")

# Reconstructed Images
for i, k in enumerate(k_values):
    plt.subplot(2,3,i+2)
    plt.imshow(reconstructed_images[i], cmap='gray')
    plt.title(f"Reconstructed (k={k})")
    plt.axis("off")

plt.tight_layout()
plt.show()
